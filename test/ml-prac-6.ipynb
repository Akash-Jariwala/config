# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv")

# %% [markdown]
# 2. Display the dataset

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 3. Find out if any column contains Null values. Display true or false for each
# column

# %%
data.isnull().sum() #total null values in each column

for c in list(data.columns):
    print("Column: ",c)
    print("Total_null_entries: ",data[c].isnull().sum())
    if data[c].isnull().sum():
        print("contains_null: True")
    else:
        print("contain_null: False")
    print(" -------------------------- ")
# Out:
# Column:  pclass
# Total_null_entries:  1
# contains_null: True
#  --------------------------
# Column:  survived
# Total_null_entries:  1
# contains_null: True
#  --------------------------
# Column:  name
# Total_null_entries:  1
# contains_null: True
#  --------------------------
# Column:  sex
# Total_null_entries:  1
# contains_null: True
#  --------------------------
# Column:  age
# Total_null_entries:  264
# contains_null: True
#  --------------------------
# Column:  sibsp
# Total_null_entries:  1
# contains_null: True
#  --------------------------
# Column:  parch
# Total_null_entries:  1
# contains_null: True
#  --------------------------
# Column:  ticket
# Total_null_entries:  1
# contains_null: True
#  --------------------------
# Column:  fare
# Total_null_entries:  2
# contains_null: True
#  --------------------------
# Column:  cabin
# Total_null_entries:  1015
# contains_null: True
#  --------------------------
# Column:  embarked
# Total_null_entries:  3
# ...

# %% [markdown]
# 4. If there is any row that contains all NaN(Null) values, drop that row.

# %%
data.dropna(thresh=13).reset_index().isnull().sum()
# Out:
# index          0
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          0
# embarked       0
# boat          27
# body         159
# home.dest      0
# dtype: int64

# %% [markdown]
# 5. Check each column data type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %% [markdown]
# 6. Generate descriptive statistics using describe()

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# 7. Fill NaN values of each column with either of the following methods:
#
# a. Fill Missing DataFrame Values with Column Mean, Median or Mode
#
# b. Fill Missing DataFrame Values with a Constant
#
# c. Forward Fill/Backward Fill Missing DataFrame Values

# %%
data['pclass'] = data['pclass'].fillna(data['pclass'].mean())
data['survived'] = data['survived'].fillna(data['survived'].mean())
data['age'] = data['age'].fillna(data['age'].mean())
data['sibsp'] = data['sibsp'].fillna(data['sibsp'].mean())
data['parch'] = data['parch'].fillna(data['parch'].mean())
data['fare'] = data['fare'].fillna(data['fare'].mean())
data
# Out:
#         pclass  survived                                             name  \
# 0     1.000000  1.000000                    Allen, Miss. Elisabeth Walton
# 1     1.000000  1.000000                   Allison, Master. Hudson Trevor
# 2     1.000000  0.000000                     Allison, Miss. Helen Loraine
# 3     1.000000  0.000000             Allison, Mr. Hudson Joshua Creighton
# 4     1.000000  0.000000  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...        ...       ...                                              ...
# 1305  3.000000  0.000000                            Zabour, Miss. Thamine
# 1306  3.000000  0.000000                        Zakarian, Mr. Mapriededer
# 1307  3.000000  0.000000                              Zakarian, Mr. Ortin
# 1308  3.000000  0.000000                               Zimmerman, Mr. Leo
# 1309  2.294882  0.381971                                              NaN
#
#          sex        age     sibsp     parch  ticket        fare    cabin  \
# ...

# %% [markdown]
# 8. Convert appropriate columns(which are of type object) into numeric data
# types

# %%
data['pclass'] = pd.to_numeric(data['pclass'])
data['survived'] = pd.to_numeric(data['survived'])
# data['name'] = pd.to_numeric(data['name'])
# data['sex'] = pd.to_numeric(data['sex'])
data['sibsp'] = pd.to_numeric(data['sibsp'])
data['parch'] = pd.to_numeric(data['parch'])
# data['ticket'] = pd.to_numeric(data['ticket'])
data['fare'] = pd.to_numeric(data['fare'])
# data['cabin'] = pd.to_numeric(data['cabin'])
# data['embarked'] = pd.to_numeric(data['embarked'])
# data['boat'] = pd.to_numeric(data['boat'])
data['body'] = pd.to_numeric(data['body'])
# data['home.dest'] = pd.to_numeric(data['home.dest'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    7 non-null      float64
#  1   survived  7 non-null      float64
#  2   age       7 non-null      float64
#  3   sibsp     7 non-null      float64
#  4   parch     7 non-null      float64
#  5   fare      7 non-null      float64
#  6   body      7 non-null      float64
# dtypes: float64(7)
# memory usage: 520.0 bytes

# %% [markdown]
# 9. Plot each numeric column with a box plot

# %%
data = pd.DataFrame(data = np.random.random(size=(7,7)), columns = ['pclass','survived','age','sibsp', 'parch', 'fare', 'body'])
data.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 10. Identify outliers for any two columns and take appropriate steps.

# %%
Q1 = data.quantile(0.25) #for each column
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print("IQR",IQR)

lower=Q1-1.5 * IQR
print("------lOWER Range-----")
print(lower)

print("------Upper Range-----")
upper=Q3 + 1.5 * IQR
print(upper)

df_outliers = data[((data < lower) |(data > upper)).any(axis=1)]
print("outlier_shape: ",df_outliers.shape)
# Out:
# IQR pclass      0.614344
# survived    0.350320
# age         0.531033
# sibsp       0.314842
# parch       0.606767
# fare        0.331364
# body        0.394683
# dtype: float64
# ------lOWER Range-----
# pclass     -0.766256
# survived   -0.375790
# age        -0.395516
# sibsp      -0.370958
# parch      -0.734364
# fare       -0.414842
# body       -0.258214
# dtype: float64
# ------Upper Range-----
# pclass      1.691122
# survived    1.025490
# age         1.728616
# sibsp       0.888409
# parch       1.692706
# fare        0.910614
# body        1.320516
# dtype: float64
# outlier_shape:  (0, 7)

# %%
df_outliers
# Out:
# Empty DataFrame
# Columns: [pclass, survived, age, sibsp, parch, fare, body]
# Index: []

# %%
df_out_final = data[~((data < lower) |(data > upper)).any(axis=1)] #removing outlier...remaining data
print(df_out_final.shape)
plt.boxplot(df_out_final.survived)
# Out:
# (7, 7)
# {'whiskers': [<matplotlib.lines.Line2D at 0x20e2d9a5040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20e2d9a5820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20e2d8b6f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x20e2d9a51c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20e2d9a7340>],
#  'means': []}

# %%
Q1 = data["survived"].quantile(0.25)
Q3 = data["survived"].quantile(0.75)
IQR = Q3 - Q1
print("IQR: ",IQR)
lower=Q1-1.5 * IQR
print("lower",lower)
upper=Q3 + 1.5 * IQR
print("Upper",upper)
data.loc[(data["survived"] >upper),"survived"]=data["survived"].quantile(0.95)
data.loc[(data["survived"] <lower),"survived"]=data["survived"].quantile(0.05)
# Out:
# IQR:  0.350319942829277
# lower -0.375789883050433
# Upper 1.025489888266675

# %%
Q1 = data["parch"].quantile(0.25) 
Q3 = data["parch"].quantile(0.75)
IQR = Q3 - Q1
print("IQR: ",IQR)
lower=Q1-1.5 * IQR
print("Lower: ",lower)
upper=Q3 + 1.5 * IQR
print("Upper",upper)
data.loc[(data["parch"] >upper),"parch"]=data["parch"].quantile(0.95)
data.loc[(data["parch"] <lower),"parch"]=data["parch"].quantile(0.05)
# Out:
# IQR:  0.6067674598271281
# Lower:  -0.7343643177364513
# Upper 1.6927055215720612

# %%
df = pd.DataFrame(data = np.random.random(size=(7,7)), columns = ['pclass','survived','age','sibsp', 'parch', 'fare', 'body'])
df.boxplot()
# Out:
# <AxesSubplot:>
